# %% [markdown]
# <a href="https://colab.research.google.com/github/tylerganter/fun_in_colabs/blob/master/notebooks/scientific_computing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1000) / 1000 * 2
y = np.sin(2 * np.pi * x)

# %%
plt.plot(x, y)
